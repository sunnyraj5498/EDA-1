# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.pandas.set_option('display.max_columns',None)

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
## print dataset shape with row and column
print(df.shape)
# Out:
# (1460, 81)

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
feature_nan=[features for features in df.columns if df[features].isnull().sum()>1]

# %%
feature_nan
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
df['Electrical'].isnull().mean()
# Out:
# 0.0006849315068493151

# %%
for feature in feature_nan:
    print(feature,np.round(df[feature].isnull().mean()*100,4),'% of nan value')
# Out:
# LotFrontage 17.7397 % of nan value
# Alley 93.7671 % of nan value
# MasVnrType 0.5479 % of nan value
# MasVnrArea 0.5479 % of nan value
# BsmtQual 2.5342 % of nan value
# BsmtCond 2.5342 % of nan value
# BsmtExposure 2.6027 % of nan value
# BsmtFinType1 2.5342 % of nan value
# BsmtFinType2 2.6027 % of nan value
# FireplaceQu 47.2603 % of nan value
# GarageType 5.5479 % of nan value
# GarageYrBlt 5.5479 % of nan value
# GarageFinish 5.5479 % of nan value
# GarageQual 5.5479 % of nan value
# GarageCond 5.5479 % of nan value
# PoolQC 99.5205 % of nan value
# Fence 80.7534 % of nan value
# MiscFeature 96.3014 % of nan value

# %%
df=df.copy()
for feature in feature_nan:
    df[feature]=np.where(df[feature].isnull(),1,0)
    df.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   int32
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          1460 non-null   int32
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
numerical_val=[feature for feature in df.columns if df[feature].dtypes!='o']

# %%
numerical_val
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
df[numerical_val].head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street  Alley LotShape  \
# 0   1          60       RL            0     8450   Pave      1      Reg
# 1   2          20       RL            0     9600   Pave      1      Reg
# 2   3          60       RL            0    11250   Pave      1      IR1
# 3   4          70       RL            0     9550   Pave      1      IR1
# 4   5          60       RL            0    14260   Pave      1      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df[numerical_val].shape
# Out:
# (1460, 81)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street  Alley LotShape  \
# 0   1          60       RL            0     8450   Pave      1      Reg
# 1   2          20       RL            0     9600   Pave      1      Reg
# 2   3          60       RL            0    11250   Pave      1      IR1
# 3   4          70       RL            0     9550   Pave      1      IR1
# 4   5          60       RL            0    14260   Pave      1      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
feature_year=[feature for feature in numerical_val if 'Yr' in feature or 'Year' in feature]

# %%
feature_year
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
df=df.copy()
for feature in feature_year:
    if feature!='YrSold':
        df[feature]=df['YrSold']-df[feature]
    
        plt.scatter(df[feature],df['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.show()

# %% [markdown]
# ## From the above given information we concludes that new  Houses are more costly then the old one looks like perito or power law distribution

# %%
df.groupby('YrSold')['SalePrice'].median().plot()
# Out:
# <Axes: xlabel='YrSold'>

# %%
discrite_feature=[feature for feature in numerical_val if len(df[feature].unique())>=25]

# %%
discrite_feature
# Out:
# ['Id',
#  'LotArea',
#  'Neighborhood',
#  'YearBuilt',
#  'YearRemodAdd',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
df[discrite_feature].head()
# Out:
#    Id  LotArea Neighborhood  YearBuilt  YearRemodAdd  BsmtFinSF1  BsmtFinSF2  \
# 0   1     8450      CollgCr          5             5         706           0
# 1   2     9600      Veenker         31            31         978           0
# 2   3    11250      CollgCr          7             6         486           0
# 3   4     9550      Crawfor         91            36         216           0
# 4   5    14260      NoRidge          8             8         655           0
#
#    BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  GarageArea  \
# 0        150          856       856       854       1710         548
# 1        284         1262      1262         0       1262         460
# 2        434          920       920       866       1786         608
# 3        540          756       961       756       1717         642
# 4        490         1145      1145      1053       2198         836
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  ScreenPorch  SalePrice
# ...

# %%
df=df.copy()
for feature in discrite_feature:
    df.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.show()
